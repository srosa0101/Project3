# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#importing CSV file

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/NYPD_Arrest_Data__Year_to_Date__20240104 (3).csv')

# %%
#Verifying the file imported correctly
df.head(20)
# Out:
#     ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0    261209118  01/01/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 1    262984267  02/03/2023    515     CONTROLLED SUBSTANCE,SALE 3  117.0
# 2    263664549  02/15/2023    105               STRANGULATION 1ST  106.0
# 3    261345231  01/04/2023    105               STRANGULATION 1ST  106.0
# 4    263536618  02/13/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 5    262030390  01/17/2023    105               STRANGULATION 1ST  106.0
# 6    262362214  01/23/2023    105               STRANGULATION 1ST  106.0
# 7    264579718  03/04/2023    153                          RAPE 3  104.0
# 8    262500981  01/25/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 9    265281035  03/17/2023    244   BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 10   262721715  01/30/2023    263                     ARSON 2,3,4  114.0
# 11   262906326  02/02/2023    101                       ASSAULT 3  344.0
# ...

# %%
df = pd.read_csv('/content/drive/MyDrive/NYPD_Arrest_Data__Year_to_Date__20240104 (3).csv')
df2 = df[['PD_DESC','OFNS_DESC','ARREST_BORO','AGE_GROUP','PERP_SEX','PERP_RACE']]

# %%
df2.head(15)
# Out:
#                            PD_DESC                     OFNS_DESC ARREST_BORO  \
# 0         ASSAULT 2,1,UNCLASSIFIED                FELONY ASSAULT           K
# 1      CONTROLLED SUBSTANCE,SALE 3               DANGEROUS DRUGS           K
# 2                STRANGULATION 1ST                FELONY ASSAULT           K
# 3                STRANGULATION 1ST                FELONY ASSAULT           M
# 4         ASSAULT 2,1,UNCLASSIFIED                FELONY ASSAULT           K
# 5                STRANGULATION 1ST                FELONY ASSAULT           Q
# 6                STRANGULATION 1ST                FELONY ASSAULT           M
# 7                           RAPE 3                          RAPE           K
# 8   FORGERY,ETC.,UNCLASSIFIED-FELO                       FORGERY           M
# 9    BURGLARY,UNCLASSIFIED,UNKNOWN                      BURGLARY           M
# 10                     ARSON 2,3,4                         ARSON           K
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['ARREST_BORO'].value_counts()
    for x_label, grp in _df_4.groupby('OFNS_DESC')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('OFNS_DESC')
_ = plt.ylabel('ARREST_BORO')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['PERP_SEX'].value_counts()
    for x_label, grp in _df_6.groupby('AGE_GROUP')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('AGE_GROUP')
_ = plt.ylabel('PERP_SEX')

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['AGE_GROUP'].value_counts()
    for x_label, grp in _df_5.groupby('ARREST_BORO')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('ARREST_BORO')
_ = plt.ylabel('AGE_GROUP')

# %%
df2.groupby(['OFNS_DESC'])['ARREST_BORO'].count()
# Out:
# OFNS_DESC
# (null)                                    13
# ADMINISTRATIVE CODE                      160
# ADMINISTRATIVE CODES                       1
# AGRICULTURE & MRKTS LAW-UNCLASSIFIED      49
# ALCOHOLIC BEVERAGE CONTROL LAW           118
#                                         ...
# THEFT OF SERVICES                        111
# THEFT-FRAUD                              155
# UNAUTHORIZED USE OF A VEHICLE            495
# UNLAWFUL POSS. WEAP. ON SCHOOL             1
# VEHICLE AND TRAFFIC LAWS                9442
# Name: ARREST_BORO, Length: 64, dtype: int64

# %%
#After analyzing the data the highest arrest across the Boroughs seems to be within Brooklyn and it appears to be among the age group falling between 25-44. It also seems that the high crime within Brooklyn is Felony Assault
